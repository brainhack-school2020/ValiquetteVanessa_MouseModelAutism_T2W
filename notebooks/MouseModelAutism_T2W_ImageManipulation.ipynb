# %%
# Import zip files

import io
import zipfile

zip_buffer = io.BytesIO()
with zipfile.ZipFile(zip_buffer, "a", zipfile.ZIP_DEFLATED, False) as zip_file:
    for file_name, data in [('1.txt', io.BytesIO(b'111')), ('2.txt', io.BytesIO(b'222'))]:
        zip_file.writestr(file_name, data.getvalue())
with open('C:/1.zip', 'wb') as f:
    f.write(zip_buffer.getvalue())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-28d9ac65b64f> in <module>
#       6     for file_name, data in [('1.txt', io.BytesIO(b'111')), ('2.txt', io.BytesIO(b'222'))]:
#       7         zip_file.writestr(file_name, data.getvalue())
# ----> 8 with open('C:/1.zip', 'wb') as f:
#       9     f.write(zip_buffer.getvalue())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/1.zip'

# %%
import nibabel as nib
import os
import numpy as np

from nibabel.testing import data_path

from nilearn import plotting

# %% [markdown]
# ## Nibabel

# %%
# Mouse Model Autism T2W images from Jason Lerch available dataset on Brain-CODE
# Downloaded only data from project PND12 and 13 (15q11-13 mice model)

#data_path = '//home/vvaliquette/MouseModelAutism_T2W/data/raw/SPAggregate_results_2020-05-19_13_53_13'
data_path = '//home/vvaliquette/MouseModelAutism_T2W/data/raw/SPAggregate_results_2020-05-19_13_53_13/PND12_HSC_0001_01_SE01_MR/scans/MR_MINC-mice_ex_vivo_fixedbrain_56um/resources/Scan_To_Study_Relative_Jacobians/files'
#image_path = '\\Users\Vanessa\Downloads\\SPAggregate_results_2020-05-19_13_53_13\TT_Mat_15q_529.march2014_dist_corr.mnc\\'

#/PND12_HSC_0001_01_SE01_MR/scans/MR_MINC-mice_ex_vivo_fixedbrain_56um/resources #Once there can pick Raw or processed files
#/Scan_To_Study_Relative_Jacobians/files
# /TT_15q_717.jan2011_distortion_corrected-final-nlin_with_additional_inverted_pure_nlin_relative_log_determinant_fwhm0.2.mnc
image = os.path.join(data_path, 'TT_15q_717.jan2011_distortion_corrected-final-nlin_with_additional_inverted_pure_nlin_relative_log_determinant_fwhm0.2.mnc')

# %%
img = nib.load(image)
data = img.get_fdata()
#print(data.mean())

# %%
plotting.plot_img(image)
